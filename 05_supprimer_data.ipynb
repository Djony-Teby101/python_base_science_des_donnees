# %%
import pandas as pd
df=pd.read_csv("data.csv")

# %%
df.head(3)
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
#
#        ip_address        country price_paid   tax
# 0   160.119.8.119         Canada      $5.36   NaN
# 1  210.51.172.132         Canada      $8.32   NaN
# 2   213.8.101.145  United States      $3.73  20.0

# %% [markdown]
# # SUPPRIMER DE LA DATA

# %%
df.drop("ip_address", axis=1, inplace= True)

# %%
df.head(3)
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
#
#          country price_paid   tax
# 0         Canada      $5.36   NaN
# 1         Canada      $8.32   NaN
# 2  United States      $3.73  20.0

# %%
df.set_index("gender", inplace=True)

# %%
df.head(3)
# Out:
#         id        date first_name   last_name                  email  \
# gender
# Male     1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp
# Female   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org
# Male     3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com
#
#               country price_paid   tax
# gender
# Male           Canada      $5.36   NaN
# Female         Canada      $8.32   NaN
# Male    United States      $3.73  20.0

# %%
df.drop("Male", axis=0, inplace=True)

# %%
df.head(3)
# Out:
#         id        date first_name   last_name                 email  \
# gender
# Female   2  03/19/2021      Hinda    Harridge    hharridge1@gnu.org
# Female   4  03/19/2021      Grata      Brantl      gbrantl3@umn.edu
# Female   6  03/25/2021      Titos  Braybrooke  tbraybrooke5@umn.edu
#
#               country price_paid   tax
# gender
# Female         Canada      $8.32   NaN
# Female  United States      $3.70  20.0
# Female  United States      $5.82   NaN

# %%
df.drop("price_paid", axis=1)
# Out:
#           id        date first_name     last_name                       email  \
# gender
# Female     2  03/19/2021      Hinda      Harridge          hharridge1@gnu.org
# Female     4  03/19/2021      Grata        Brantl            gbrantl3@umn.edu
# Female     6  03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu
# Female     7  03/14/2021        Ava       Kencott          akencott6@phoca.cz
# Female    13  03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn
# ...      ...         ...        ...           ...                         ...
# NaN      990  03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org
# Female   995  03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com
# Female   996  03/24/2021       Duff        Errigo        derrigorn@elpais.com
# Female   997  03/17/2021        Ame       Rastall       arastallro@toplist.cz
# NaN     1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov
#
# ...

# %%
df.drop(["first_name","last_name"], axis=1)
# Out:
#           id        date                       email        country  \
# gender
# Female     2  03/19/2021          hharridge1@gnu.org         Canada
# Female     4  03/19/2021            gbrantl3@umn.edu  United States
# Female     6  03/25/2021        tbraybrooke5@umn.edu  United States
# Female     7  03/14/2021          akencott6@phoca.cz         Canada
# Female    13  03/05/2021  jmorillasc@miibeian.gov.cn         Canada
# ...      ...         ...                         ...            ...
# NaN      990  03/16/2021    hvanarsdalenrh@prlog.org         France
# Female   995  03/17/2021   cbruntjenrm@reference.com         France
# Female   996  03/24/2021        derrigorn@elpais.com         France
# Female   997  03/17/2021       arastallro@toplist.cz            NaN
# NaN     1000  03/23/2021       rpringuerrr@house.gov         Canada
#
#        price_paid   tax
# gender
# Female      $8.32   NaN
# Female      $3.70  20.0
# Female      $5.82   NaN
# Female      $6.29   NaN
# ...

# %%
del df["email"]=="hharridge1@gnu.org"
# Out:
#   Cell In[13], line 1
#     del df["email"]=="hharridge1@gnu.org"
#         ^
# SyntaxError: cannot delete comparison

# %%
df.drop("email" ,axis=1)
# Out:
#           id        date first_name     last_name        country price_paid  \
# gender
# Female     2  03/19/2021      Hinda      Harridge         Canada      $8.32
# Female     4  03/19/2021      Grata        Brantl  United States      $3.70
# Female     6  03/25/2021      Titos    Braybrooke  United States      $5.82
# Female     7  03/14/2021        Ava       Kencott         Canada      $6.29
# Female    13  03/05/2021     Janice      Morillas         Canada      $5.30
# ...      ...         ...        ...           ...            ...        ...
# NaN      990  03/16/2021   Horatius  Van Arsdalen         France      $8.69
# Female   995  03/17/2021   Carolyne      Bruntjen         France      $5.68
# Female   996  03/24/2021       Duff        Errigo         France      $3.63
# Female   997  03/17/2021        Ame       Rastall            NaN      $4.59
# NaN     1000  03/23/2021   Rochelle      Pringuer         Canada      $8.01
#
#          tax
# gender
# Female   NaN
# ...

# %%
del df["email"]

# %%
df.head(3)
# Out:
#         id        date first_name   last_name        country price_paid   tax
# gender
# Female   2  03/19/2021      Hinda    Harridge         Canada      $8.32   NaN
# Female   4  03/19/2021      Grata      Brantl  United States      $3.70  20.0
# Female   6  03/25/2021      Titos  Braybrooke  United States      $5.82   NaN

# %%
del df["first_name"]

# %%
df.drop(["last_name","id"], axis=1, inplace=True)

# %%
df
# Out:
#               date        country price_paid   tax
# gender
# Female  03/19/2021         Canada      $8.32   NaN
# Female  03/19/2021  United States      $3.70  20.0
# Female  03/25/2021  United States      $5.82   NaN
# Female  03/14/2021         Canada      $6.29   NaN
# Female  03/05/2021         Canada      $5.30  20.0
# ...            ...            ...        ...   ...
# NaN     03/16/2021         France      $8.69  20.0
# Female  03/17/2021         France      $5.68  20.0
# Female  03/24/2021         France      $3.63   NaN
# Female  03/17/2021            NaN      $4.59  20.0
# NaN     03/23/2021         Canada      $8.01  20.0
#
# [562 rows x 4 columns]

# %%
df["date"]=="03/19/2021"
# Out:
# gender
# Female     True
# Female     True
# Female    False
# Female    False
# Female    False
#           ...
# NaN       False
# Female    False
# Female    False
# Female    False
# NaN       False
# Name: date, Length: 562, dtype: bool

# %%
delete_session=df[df["date"]=="03/19/2021"]

# %%
delete_session.head(3)
# Out:
#               date        country price_paid   tax
# gender
# Female  03/19/2021         Canada      $8.32   NaN
# Female  03/19/2021  United States      $3.70  20.0
# Female  03/19/2021  United States      $5.92   NaN

# %%
df.drop(delete_session, axis=1, inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [Female, Female, Female, Female, Female, nan, Female, Female, Female, nan, Female, Female, Female, nan, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, nan, Female, nan, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, nan, Female, Female, Female, Female, nan, Female, nan, Female, Female, nan, Female, Female, Female, Female, Female, Female, Female, nan, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, nan, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, nan, Female, Female, Female, Female, Female, Female, nan, Female, nan, Female, Female, Female, Female, ...]
#
# [562 rows x 0 columns]
